# %% [markdown]
# # Nexu bod notes from _________ to 18_4_26
#
#
# ## Mics
# /home/faso/IT/gideone-bus/gideone_bus_scaffold/libs/infrastructure/settings/config.py
#
# redis-server --maxmemory 2gb
# redis-cli CONFIG REWRITE
